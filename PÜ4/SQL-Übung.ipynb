# %% [markdown]
# # SQL
#
# ## Vorbereitung des Notebooks
#
# Hier nichts verändern.

# %%
# Installiert Paket, damit man SQL-Befehle auf Dataframes anwenden kann
# %pip install pandasql

# Lädt Paket, damit man Dataframes (Tabellen in Python) anwenden kann
import pandas as pd
# Lädt Paket, damit man SQL-Befehle auf Dataframes anwenden kann
import pandasql as ps
# Out:
# Requirement already satisfied: pandasql in c:\users\johannes\appdata\local\programs\python\python39\lib\site-packages (0.7.3)
# Requirement already satisfied: numpy in c:\users\johannes\appdata\local\programs\python\python39\lib\site-packages (from pandasql) (1.22.3)
# Requirement already satisfied: pandas in c:\users\johannes\appdata\local\programs\python\python39\lib\site-packages (from pandasql) (1.4.1)
# Requirement already satisfied: sqlalchemy in c:\users\johannes\appdata\local\programs\python\python39\lib\site-packages (from pandasql) (1.4.35)
# Requirement already satisfied: pytz>=2020.1 in c:\users\johannes\appdata\local\programs\python\python39\lib\site-packages (from pandas->pandasql) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\johannes\appdata\local\programs\python\python39\lib\site-packages (from pandas->pandasql) (2.8.2)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\johannes\appdata\local\programs\python\python39\lib\site-packages (from sqlalchemy->pandasql) (1.1.2)
# Requirement already satisfied: six>=1.5 in c:\users\johannes\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.8.1->pandas->pandasql) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Datenbeschreibung
#
# Performance_data ist ein Datensatz über vorangegangene Leistungstests ([VO2_max](https://de.wikipedia.org/wiki/Maximale_Sauerstoffaufnahme)). Zudem enthält es Informationen über das Geschlecht und Alter der Untersuchten, ob diese rauchen oder nicht, deren Körpergröße und Gewicht, sowie die die Diagnostiker:in, die den Test durchgeführt hat. Zudem wird der Erlös erhoben, der bei der Krankenkasse für die Diagnostik verrechnet wurde.
#
# ### Aufgabe
#
# Laden die die Daten in einen pandas DataFrame und zeigen Sie diese an. (Hinweis: wir nutzen hier die Möglichkeit mit SQL-Befehlen direkt auf einem Pandas DataFrame in Arbeitsspeicher des PCs zu arbeiten. Hierdurch sparen wir uns das Aufsetzen einer echten Datenbank.)

# %%
# Lösung
# Lade die Daten in einen pandas Dataframe namens "performance_data"
performance_data = pd.read_csv("test_data.csv")

# Zeige performance_data an
performance_data
# Out:
#      Unnamed: 0  VO2_max  age  smoker  height  weight  revenue  \
# 0             0       45   66    True     165      76       30
# 1             1       37   58   False     180      87       32
# 2             2       54   27   False     155      62       29
# 3             3       58   32   False     183      78       26
# 4             4       45   75    True     166     101       10
# ..          ...      ...  ...     ...     ...     ...      ...
# 195         195       55   24    True     160      74       11
# 196         196       46   17   False     172      92       18
# 197         197       61   52   False     164      84       29
# 198         198       67   46    True     164      78       39
# 199         199       43   39   False     162     107       36
#
#      diagnostician_id  gender
# 0                   2    Male
# 1                   1  Female
# 2                   0    Male
# 3                   0    Male
# 4                   2  Female
# ..                ...     ...
# 195                 3    Male
# 196                 3    Male
# 197                 0  Female
# 198                 1    Male
# 199                 1    Male
#
# [200 rows x 9 columns]

# %% [markdown]
# ## SQL-Befehle
#
# ```ps.sqldf()``` Ist eine Funktion die es erlaubt SQL-Befehle statt auf Daten auf pandas Dataframes auszuführen. Der Funktion wird der eigentliche SQL-Befehl als Sting übergeben:
#
# ```"SELECT * FROM performance_data"```
#
# SELECT und FROM sind Schlüsselwörter der SQL-Sprache und werden deswegen großgeschrieben. ```performance_data``` ist der Name der Tabelle/Relation von der wir abfragen wollen. das ```*``` ist eine sogenannte Wildcard und bedeuted, dass wir alle Attribute der Tabelle ausgeben wollen:
#
#
# ```ps.sqldf("SELECT * FROM performance_data") # Gibt die gesamte Tabelle performance_data aus```
#
#
# [Hier](https://www.dataquest.io/blog/sql-basics/) findet sich eine ausfühliche Erklärung dieser und weiterer SQL-Befehle.

# %%
ps.sqldf("SELECT * FROM performance_data") # Gibt die gesamte Tabelle performance_data aus
# Out:
#      Unnamed: 0  VO2_max  age  smoker  height  weight  revenue  \
# 0             0       45   66       1     165      76       30
# 1             1       37   58       0     180      87       32
# 2             2       54   27       0     155      62       29
# 3             3       58   32       0     183      78       26
# 4             4       45   75       1     166     101       10
# ..          ...      ...  ...     ...     ...     ...      ...
# 195         195       55   24       1     160      74       11
# 196         196       46   17       0     172      92       18
# 197         197       61   52       0     164      84       29
# 198         198       67   46       1     164      78       39
# 199         199       43   39       0     162     107       36
#
#      diagnostician_id  gender
# 0                   2    Male
# 1                   1  Female
# 2                   0    Male
# 3                   0    Male
# 4                   2  Female
# ..                ...     ...
# 195                 3    Male
# 196                 3    Male
# 197                 0  Female
# 198                 1    Male
# 199                 1    Male
#
# [200 rows x 9 columns]

# %% [markdown]
# ## Projektion
#
# Durch eine Projektion werden einzelne Attribute aus einer Tabelle abgefragt. Hierzu werden die Attribute hinter der SELECT genannt und mit einen Komma voneinander abgetrennt.
#
# ```ps.sqldf("SELECT gender FROM performance_data") # Gibt sex aus```
#
#
# ```ps.sqldf("SELECT gender, age FROM performance_data") # Gibt gender und age aus```

# %%
# Beispiel
ps.sqldf("SELECT gender FROM performance_data") # Gibt sex aus
# Out:
#      gender
# 0      Male
# 1    Female
# 2      Male
# 3      Male
# 4    Female
# ..      ...
# 195    Male
# 196    Male
# 197  Female
# 198    Male
# 199    Male
#
# [200 rows x 1 columns]

# %%
# Beispiel
ps.sqldf("SELECT gender, age FROM performance_data") # Gibt gender und age aus
# Out:
#      gender  age
# 0      Male   66
# 1    Female   58
# 2      Male   27
# 3      Male   32
# 4    Female   75
# ..      ...  ...
# 195    Male   24
# 196    Male   17
# 197  Female   52
# 198    Male   46
# 199    Male   39
#
# [200 rows x 2 columns]

# %% [markdown]
# ## Selektion
#
# Auswahl einer Untermenge aller Tupel einer Tabelle.
# Die Selektion wird durch zusätzliche Schlüsselwörter hinter der Auswahl der Tabelle (FROM performance_data) angefügt.
#
# Beispielsweise lässt sich die Ausgabe auf fünf Einträge begrenzen:
#
# ```ps.sqldf("SELECT gender, age FROM performance_data LIMIT 5")```

# %%
# Beispiel
ps.sqldf("SELECT gender, age FROM performance_data LIMIT 5") # Gibt die ersten  Einträge aus
# Out:
#    gender  age
# 0    Male   66
# 1  Female   58
# 2    Male   27
# 3    Male   32
# 4  Female   75

# %% [markdown]
# ### Filtern
#
# - Eine besondere Art von Selektion ist das Filtern
# - Beim Filtern wird das Schlüsselwort ```WHERE``` genutzt. Darauf folgt eine logische Abfrage z.B. bezüglich des Attributs ```smoker``` ob dieses den Wert False enthält.
#
# ```ps.sqldf("""SELECT gender, age, smoker FROM performance_data WHERE smoker=False """)```
#
# *Vorsicht: der SQL-Befehl enthält " um den String zu kennzeichnen. Damit Python diesen nicht mit dem Anfang und Ende der SQL-Abfrage verwechselt, wird diese jetzt mit """ (drei ") gekennzeichnet *

# %%
# Beispiel
ps.sqldf("""SELECT gender, age, smoker FROM performance_data WHERE smoker=0 """)
# Out:
#      gender  age  smoker
# 0    Female   58       0
# 1      Male   27       0
# 2      Male   32       0
# 3    Female   71       0
# 4      Male   28       0
# ..      ...  ...     ...
# 96   Female   71       0
# 97     Male   70       0
# 98     Male   17       0
# 99   Female   52       0
# 100    Male   39       0
#
# [101 rows x 3 columns]

# %% [markdown]
# Filter-Operationen können auch vergleichend sein (größer, kleiner, etc.) und können mit logischen Operatoren verknüpft werden:

# %%
# Beispiel
ps.sqldf("""SELECT * FROM performance_data WHERE weight<70 AND  height>185""")
# Out:
#    Unnamed: 0  VO2_max  age  smoker  height  weight  revenue  \
# 0          13       51   53       1     186      68       27
# 1         135       62   28       0     188      67       39
# 2         175       34   60       0     189      64       15
# 3         184       39   54       0     186      67       13
#
#    diagnostician_id  gender
# 0                 0    Male
# 1                 3    Male
# 2                 3  Female
# 3                 2    Male

# %% [markdown]
# ## Ausgaben verarbeiten

# %% [markdown]
# ### Sortieren
#
# Ausgeben können auch weiterverarbeitet werden, um beispielsweise Reports zu erstellen.
#
# Hier werden durch das Kennwort ```ASC``` die Ausgaben nach dem davor genannten Attribut ```VO2_max``` geordnet ausgegeben.
#
# ```
# ps.sqldf("SELECT gender, VO2_max FROM performance_data ORDER BY VO2_max ASC")
# ```

# %%
# Beispiel
ps.sqldf("SELECT gender, VO2_max FROM performance_data ORDER BY VO2_max ASC")
# Out:
#      gender  VO2_max
# 0    Female       30
# 1    Female       30
# 2    Female       30
# 3      Male       30
# 4    Female       30
# ..      ...      ...
# 195    Male       69
# 196  Female       69
# 197    Male       69
# 198  Female       69
# 199  Female       69
#
# [200 rows x 2 columns]

# %% [markdown]
# ### Aggregation
#
# Über der Schlüsselwort ```SUM``` lassen sich Summen über Attribute bilden.
#
# ```
# ps.sqldf("""SELECT SUM(revenue) FROM performance_data""")
# ```

# %%
# Beispiel
ps.sqldf("""SELECT SUM(revenue) FROM performance_data""")
# Out:
#    SUM(revenue)
# 0          5776

# %% [markdown]
# Es lassen sich auch Summen über mehrere Attribute erzeugen, z.B. um die Raucher und den gesamten Umsatz zu zählen:
#
# ```
# ps.sqldf("""SELECT SUM(revenue), SUM(smoker) FROM performance_data""")
# ```

# %%
# Beispiel
ps.sqldf("""SELECT SUM(revenue), SUM(smoker) FROM performance_data""")
# Out:
#    SUM(revenue)  SUM(smoker)
# 0          5776           99

# %% [markdown]
# Oder die Summen über ein Subset (Selektion) bilden.
#
# Hier werden z.B. nur die Erlöse der Raucher summiert:
#
# ```
# ps.sqldf("""SELECT SUM(revenue) FROM performance_data WHERE smoker=1 """)
# ```

# %%
# Beispiel
ps.sqldf("""SELECT SUM(revenue) FROM performance_data WHERE smoker=1 """)
# Out:
#    SUM(revenue)
# 0          2833

# %% [markdown]
# Es gibt auch weitere Befehle zur Aggregation, wie z.B. ```COUNT```
# Hier werden alle Tupel (Zeilen in der Tabelle) gezählt:
#
# ```
# ps.sqldf("""SELECT COUNT(*) FROM performance_data""")
# ```

# %%
# Beispiel
ps.sqldf("""SELECT COUNT(*) FROM performance_data""")
# Out:
#    COUNT(*)
# 0       200

# %% [markdown]
# Neben der Summation gibt es noch weitere Operationen, um das Minimum (```MIN```), Maximum (```MAX```) oder den Durchschnitt (```AVG```) zu finden.
#
# So lässt sich zum Beispiel die durchschnittliche Leistung der getesteten bestimmen:
# ```ps.sqldf(""" SELECT AVG(VO2_max) FROM performance_data """) ```

# %%
# Lösung
ps.sqldf(""" SELECT AVG(VO2_max) FROM performance_data WHERE weight < 80 """)
# Out:
#    AVG(VO2_max)
# 0     48.170455

# %% [markdown]
# ### Gruppieren
#
# Operationen, wie ```AVG``` lassen sich mit den Schlüsselwort ```GROUP BY``` automatisiert für mehrere Gruppen durchführen.
#
# Z.B. lässt sich der VO2_max getrennt nach Geschlecht auswerten.
#
# ``` """ SELECT AVG(VO2_max), gender FROM performance_data GROUP BY gender """ ```

# %%
# Beispiel
ps.sqldf("""SELECT gender, SUM(revenue) FROM performance_data GROUP BY gender""")
# Out:
#    gender  SUM(revenue)
# 0  Female          2752
# 1    Male          3024

# %%
# Lösung
ps.sqldf("""SELECT diagnostician_id, SUM(revenue) FROM performance_data GROUP BY diagnostician_id""")
# Out:
#    diagnostician_id  SUM(revenue)
# 0                 0          1012
# 1                 1          1494
# 2                 2          1562
# 3                 3          1708

# %% [markdown]
# ### Speichern der Ergebnisse
#
# Die Ergebnisse lassen sich über eine Zuweisung in einem neuen DataFrame speichern.

# %%
# Beispiel
new_table = ps.sqldf(""" SELECT COUNT(age) FROM performance_data GROUP BY smoker """) 
print(new_table)
# Out:
#    COUNT(age)
# 0         101
# 1          99

# %% [markdown]
# ### Logische Verknüpfungen
#
# Durch die logischen Operatoren ```OR```und ```AND``` lassen sich auch komplexere Abfragen gestalten. Zum Beispiel die Suche nach besonders untersetzten Personen:
#
# ```ps.sqldf(""" SELECT AVG(VO2_max), height, weight FROM performance_data WHERE height < 170 AND weight > 90 """)```

# %%
# Beispiel
ps.sqldf(""" SELECT AVG(VO2_max), height, weight FROM performance_data WHERE height < 170 AND weight > 90 """)
# Out:
#    AVG(VO2_max)  height  weight
# 0     48.309524     162     107

# %% [markdown]
# ## Übung

# %% [markdown]
# 1. Wer sind die größten drei weiblichen Teilnehmerinnen?

# %%
ps.sqldf("""SELECT gender, height FROM performance_data WHERE gender = "Female" ORDER BY height DESC LIMIT 3""")
# Out:
#    gender  height
# 0  Female     189
# 1  Female     189
# 2  Female     187

# %% [markdown]
# 2. Was sind die höchsten vier Erlöse, die von Diagnostiker:in 2 erzielt wurden?

# %%
ps.sqldf("""SELECT diagnostician_id, revenue FROM performance_data WHERE diagnostician_id = "2" ORDER BY revenue DESC LIMIT 4""")
# Out:
#    diagnostician_id  revenue
# 0                 2       49
# 1                 2       48
# 2                 2       47
# 3                 2       47

# %% [markdown]
# 3. Wie leistungsfähig sind Personen mit einer Größe über 170 cm verglichen mit kleineren Personen? (2 Befehle)

# %%
ps.sqldf("""SELECT AVG(VO2_max) FROM performance_data WHERE height > 170 """)
# Out:
#    AVG(VO2_max)
# 0     48.953488

# %%
ps.sqldf("""SELECT AVG(VO2_max) FROM performance_data WHERE height <= 170 """)
# Out:
#    AVG(VO2_max)
# 0     48.947368

# %% [markdown]
# 4. Was ist die Durchschnittsleistung von Männern unter 80kg?

# %%
ps.sqldf("""SELECT AVG(VO2_max) FROM performance_data WHERE gender = "Male" AND weight<80 """)
# Out:
#    AVG(VO2_max)
# 0     49.978723

# %% [markdown]
# 5. Wie viel Umsatz wird mir Rauchern und Nicht-Rauchern erzielt (ein Befehl)?

# %%
ps.sqldf("""Select smoker, SUM(revenue) FROM performance_data GROUP by smoker """)
# Out:
#    smoker  SUM(revenue)
# 0       0          2943
# 1       1          2833

# %% [markdown]
# 6. Wie ist die durchschnittliche Leistung mit einem über-und unterdurchschnittlichen Gewicht? Wie sieht der Einfluss bei der größe aus?

# %%
ps.sqldf("""SELECT AVG(VO2_max) FROM performance_data WHERE weight > (Select AVG(weight) FROM performance_data)""")
# Out:
#    AVG(VO2_max)
# 0     49.865979

# %%
ps.sqldf("""SELECT AVG(VO2_max) FROM performance_data WHERE weight < (Select AVG(weight) FROM performance_data)""")
# Out:
#    AVG(VO2_max)
# 0     48.087379

# %%
ps.sqldf("""SELECT AVG(VO2_max) FROM performance_data WHERE height > (Select AVG(height) FROM performance_data)""")
# Out:
#    AVG(VO2_max)
# 0     49.747368

# %%
ps.sqldf("""SELECT AVG(VO2_max) FROM performance_data WHERE height < (Select AVG(height) FROM performance_data)""")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1817'>1818</a>     if not evt_handled:
# -> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1818'>1819</a>         self.dialect.do_execute(
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1819'>1820</a>             cursor, statement, parameters, context
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1820'>1821</a>         )
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1822'>1823</a> if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/default.py?line=730'>731</a> def do_execute(self, cursor, statement, parameters, context=None):
# --> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/default.py?line=731'>732</a>     cursor.execute(statement, parameters)
#
# OperationalError: near "SELCECT": syntax error
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandasql\sqldf.py:61, in PandaSQL.__call__(self, query, env)
#      <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=59'>60</a> try:
# ---> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=60'>61</a>     result = read_sql(query, conn)
#      <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=61'>62</a> except DatabaseError as ex:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py:592, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=590'>591</a> else:
# --> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=591'>592</a>     return pandas_sql.read_query(
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=592'>593</a>         sql,
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=593'>594</a>         index_col=index_col,
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=594'>595</a>         params=params,
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=595'>596</a>         coerce_float=coerce_float,
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=596'>597</a>         parse_dates=parse_dates,
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=597'>598</a>         chunksize=chunksize,
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=598'>599</a>     )
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py:1557, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype)
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=1554'>1555</a> args = _convert_params(sql, params)
# -> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=1556'>1557</a> result = self.execute(*args)
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=1557'>1558</a> columns = result.keys()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\io\sql.py:1402, in SQLDatabase.execute(self, *args, **kwargs)
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=1400'>1401</a> """Simple passthrough to SQLAlchemy connectable"""
# -> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandas/io/sql.py?line=1401'>1402</a> return self.connectable.execution_options().execute(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:1291, in Connection.execute(self, statement, *multiparams, **params)
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1282'>1283</a>     util.warn_deprecated_20(
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1283'>1284</a>         "Passing a string to Connection.execute() is "
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1284'>1285</a>         "deprecated and will be removed in version 2.0.  Use the "
#    (...)
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1287'>1288</a>         "driver-level SQL string."
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1288'>1289</a>     )
# -> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1290'>1291</a>     return self._exec_driver_sql(
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1291'>1292</a>         statement,
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1292'>1293</a>         multiparams,
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1293'>1294</a>         params,
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1294'>1295</a>         _EMPTY_EXECUTION_OPTS,
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1295'>1296</a>         future=False,
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1296'>1297</a>     )
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1298'>1299</a> try:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:1595, in Connection._exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1593'>1594</a> dialect = self.dialect
# -> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1594'>1595</a> ret = self._execute_context(
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1595'>1596</a>     dialect,
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1596'>1597</a>     dialect.execution_ctx_cls._init_statement,
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1597'>1598</a>     statement,
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1598'>1599</a>     distilled_parameters,
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1599'>1600</a>     execution_options,
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1600'>1601</a>     statement,
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1601'>1602</a>     distilled_parameters,
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1602'>1603</a> )
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1604'>1605</a> if not future:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:1862, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1860'>1861</a> except BaseException as e:
# -> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1861'>1862</a>     self._handle_dbapi_exception(
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1862'>1863</a>         e, statement, parameters, cursor, context
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1863'>1864</a>     )
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1865'>1866</a> return result
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:2043, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=2041'>2042</a> elif should_wrap:
# -> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=2042'>2043</a>     util.raise_(
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=2043'>2044</a>         sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=2044'>2045</a>     )
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=2045'>2046</a> else:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\util\compat.py:207, in raise_(***failed resolving arguments***)
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/util/compat.py?line=205'>206</a> try:
# --> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/util/compat.py?line=206'>207</a>     raise exception
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/util/compat.py?line=207'>208</a> finally:
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/util/compat.py?line=208'>209</a>     # credit to
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/util/compat.py?line=209'>210</a>     # https://cosmicpercolator.com/2016/01/13/exception-leaks-in-python-2-and-3/
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/util/compat.py?line=210'>211</a>     # as the __traceback__ object creates a cycle
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\base.py:1819, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1817'>1818</a>     if not evt_handled:
# -> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1818'>1819</a>         self.dialect.do_execute(
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1819'>1820</a>             cursor, statement, parameters, context
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1820'>1821</a>         )
#    <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/base.py?line=1822'>1823</a> if self._has_events or self.engine._has_events:
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\sqlalchemy\engine\default.py:732, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/default.py?line=730'>731</a> def do_execute(self, cursor, statement, parameters, context=None):
# --> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/sqlalchemy/engine/default.py?line=731'>732</a>     cursor.execute(statement, parameters)
#
# OperationalError: (sqlite3.OperationalError) near "SELCECT": syntax error
# [SQL:  SELCECT revenue FROM performance_data ORDER BY revenue DESC LIMIT 3 ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
#
# During handling of the above exception, another exception occurred:
#
# PandaSQLException                         Traceback (most recent call last)
# c:\MCI_BA_MGST_Semester_2\Programmierübung 2\MCI-MSE_Aufgaben-1\PÜ4\SQL-Übung.ipynb Cell 52' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/MCI_BA_MGST_Semester_2/Programmier%C3%BCbung%202/MCI-MSE_Aufgaben-1/P%C3%9C4/SQL-%C3%9Cbung.ipynb#ch0000051?line=0'>1</a> #ps.sqldf("""SELECT AVG(VO2_max) FROM performance_data WHERE height < (Select AVG(height) FROM performance_data)""")
# ----> <a href='vscode-notebook-cell:/c%3A/MCI_BA_MGST_Semester_2/Programmier%C3%BCbung%202/MCI-MSE_Aufgaben-1/P%C3%9C4/SQL-%C3%9Cbung.ipynb#ch0000051?line=1'>2</a> ps.sqldf(""" SELCECT revenue FROM performance_data ORDER BY revenue DESC LIMIT 3 """)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandasql\sqldf.py:156, in sqldf(query, env, db_uri)
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=123'>124</a> def sqldf(query, env=None, db_uri='sqlite:///:memory:'):
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=124'>125</a>     """
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=125'>126</a>     Query pandas data frames using sql syntax
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=126'>127</a>     This function is meant for backward compatibility only. New users are encouraged to use the PandaSQL class.
#    (...)
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=153'>154</a>     >>> sqldf("select avg(x) from df;", locals())
#     <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=154'>155</a>     """
# --> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=155'>156</a>     return PandaSQL(db_uri)(query, env)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandasql\sqldf.py:63, in PandaSQL.__call__(self, query, env)
#      <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=60'>61</a>     result = read_sql(query, conn)
#      <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=61'>62</a> except DatabaseError as ex:
# ---> <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=62'>63</a>     raise PandaSQLException(ex)
#      <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=63'>64</a> except ResourceClosedError:
#      <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=64'>65</a>     # query returns nothing
#      <a href='file:///c%3A/Users/Johannes/AppData/Local/Programs/Python/Python39/lib/site-packages/pandasql/sqldf.py?line=65'>66</a>     result = None
#
# PandaSQLException: (sqlite3.OperationalError) near "SELCECT": syntax error
# [SQL:  SELCECT revenue FROM performance_data ORDER BY revenue DESC LIMIT 3 ]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
